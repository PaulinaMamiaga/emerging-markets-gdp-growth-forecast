# %%
import os

base_path = r"C:\Users\pauli\OneDrive\Documents\GitHub"

print("Exists?", os.path.exists(base_path))
print("Folders inside GitHub:")

for item in os.listdir(base_path):
    print("-", item)
# Out:
# Exists? False
# Folders inside GitHub:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 8
#       5 print("Exists?", os.path.exists(base_path))
#       6 print("Folders inside GitHub:")
# ----> 8 for item in os.listdir(base_path):
#       9     print("-", item)
#
# FileNotFoundError: [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'C:\\Users\\pauli\\OneDrive\\Documents\\GitHub'
